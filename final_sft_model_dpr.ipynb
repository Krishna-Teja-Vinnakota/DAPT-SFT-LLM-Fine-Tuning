# %% [markdown]
# this is the final sft model, this takes the updated dapt zip( where we proceseed 5 dprs one by one ( not in one go)

# %%
# !pip install -q unsloth transformers datasets accelerate trl
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 57.4/57.4 kB 5.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.0/71.0 MB 13.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.2/10.2 MB 119.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 506.8/506.8 kB 43.2 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 423.1/423.1 kB 38.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 60.7/60.7 MB 12.7 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 48.9/48.9 MB 15.5 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 868.6/868.6 kB 59.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 119.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.6/3.6 MB 124.6 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 185.2/185.2 kB 19.4 MB/s eta 0:00:00
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.2/3.2 MB 120.3 MB/s eta 0:00:00
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a9f56738-1b34-4cfe-95cc-91979981a722" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a9f56738-1b34-4cfe-95cc-91979981a722">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
# !unzip -q updated_dpr_dapt_adapter.zip

import os
print("Files:", os.listdir())
print("Adapter contents:", os.listdir("updated_dpr_dapt_adapter"))
# Out:
# replace updated_dpr_dapt_adapter/adapter_config.json? [y]es, [n]o, [A]ll, [N]one, [r]ename: Files: ['.config', 'unsloth_compiled_cache', 'final_shuffled_dataset.json', 'huggingface_tokenizers_cache', 'sft_outputs', 'updated_dpr_dapt_adapter', 'updated_dpr_dapt_adapter.zip', 'sample_data']
# Adapter contents: ['adapter_config.json', 'chat_template.jinja', 'README.md', 'tokenizer_config.json', 'tokenizer.json', 'adapter_model.safetensors']

# %%
from unsloth import FastLanguageModel
from peft import PeftModel
import torch

BASE_MODEL = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit"

# Load base WITHOUT 4-bit so merge works cleanly
model, tokenizer = FastLanguageModel.from_pretrained(
    model_name=BASE_MODEL,
    max_seq_length=2048,
    load_in_4bit=False,      # ← changed to False
    dtype=torch.float16,
)

# Load DAPT adapter
model = PeftModel.from_pretrained(model, "updated_dpr_dapt_adapter")

# Merge — now works because model is float16, not quantized
model = model.merge_and_unload()

print("DAPT merged successfully")
# from unsloth import FastLanguageModel
# from peft import PeftModel
# import torch

# BASE_MODEL = "unsloth/Llama-3.2-3B-Instruct-bnb-4bit"

# # Load base
# model, tokenizer = FastLanguageModel.from_pretrained(
#     model_name=BASE_MODEL,
#     max_seq_length=2048,
#     load_in_4bit=True,
#     dtype=torch.float16,   #  FORCE dtype consistency
# )

# # Load DAPT adapter
# model = PeftModel.from_pretrained(model, "updated_dpr_dapt_adapter")

# #  MERGE → removes LoRA conflicts
# model = model.merge_and_unload()

# print(" DAPT merged successfully")
# Out:
# ==((====))==  Unsloth 2026.4.8: Fast Llama patching. Transformers: 5.5.0.
#    \\   /|    Tesla T4. Num GPUs = 1. Max memory: 14.563 GB. Platform: Linux.
# O^O/ \_/ \    Torch: 2.10.0+cu128. CUDA: 7.5. CUDA Toolkit: 12.8. Triton: 3.6.0
# \        /    Bfloat16 = FALSE. FA [Xformers = 0.0.35. FA2 = False]
#  "-____-"     Free license: http://github.com/unslothai/unsloth
# Unsloth: Fast downloading is enabled - ignore downloading bars which are red colored!
# model.safetensors.index.json: 0.00B [00:00, ?B/s]
# ...
# Loading weights:   0%|          | 0/254 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/234 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/890 [00:00<?, ?B/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# tokenizer.json:   0%|          | 0.00/17.2M [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/454 [00:00<?, ?B/s]
# chat_template.jinja: 0.00B [00:00, ?B/s]
# Unsloth: Will load unsloth/Llama-3.2-3B-Instruct as a legacy tokenizer.
# ...

# %%
model = FastLanguageModel.get_peft_model(
    model,
    r=16,
    target_modules=[
        "q_proj","k_proj","v_proj","o_proj",
        "gate_proj","up_proj","down_proj"
    ],
    lora_alpha=16,
    lora_dropout=0,
    bias="none",
    use_gradient_checkpointing="unsloth",
    random_state=42,
)
print("Model ready for SFT")
# model = FastLanguageModel.get_peft_model(
#     model,
#     r=16,
#     target_modules=[
#         "q_proj","k_proj","v_proj","o_proj",
#         "gate_proj","up_proj","down_proj"
#     ],
#     lora_alpha=16,
#     lora_dropout=0,
#     bias="none",
#     use_gradient_checkpointing="unsloth",
#     random_state=42,
# )

# print(" Model ready for SFT")
# Out:
# Unsloth 2026.4.8 patched 28 layers with 28 QKV layers, 28 O layers and 28 MLP layers.
# Model ready for SFT

# %%
from datasets import load_dataset

dataset = load_dataset("json", data_files="final_shuffled_dataset.json")["train"]

alpaca_prompt = """Below is an instruction that describes a task.

### Instruction:
{}

### Input:
{}

### Response:
{}"""

EOS = tokenizer.eos_token

def format_data(examples):
    texts = []
    for i in range(len(examples["instruction"])):
        text = alpaca_prompt.format(
            examples["instruction"][i],
            examples["input"][i],
            examples["output"][i],
        ) + EOS
        texts.append(text)
    return {"text": texts}

dataset = dataset.map(format_data, batched=True)

# %%
from trl import SFTTrainer
from transformers import TrainingArguments
from unsloth import is_bfloat16_supported

trainer = SFTTrainer(
    model=model,
    tokenizer=tokenizer,
    train_dataset=dataset,
    dataset_text_field="text",
    max_seq_length=2048,
    packing=False,
    args=TrainingArguments(
        per_device_train_batch_size=2,
        gradient_accumulation_steps=4,
        num_train_epochs=3,
        learning_rate=1e-4,
        fp16=not is_bfloat16_supported(),   # ← auto-detect
        bf16=is_bfloat16_supported(),        # ← auto-detect
        logging_steps=20,
        optim="adamw_8bit",
        weight_decay=0.01,
        lr_scheduler_type="cosine",
        seed=42,
        output_dir="sft_outputs",
        save_strategy="epoch",
    ),
)

print("Training starting...")
trainer.train()
# from trl import SFTTrainer
# from transformers import TrainingArguments

# trainer = SFTTrainer(
#     model=model,
#     tokenizer=tokenizer,
#     train_dataset=dataset,
#     dataset_text_field="text",
#     max_seq_length=2048,
#     packing=False,
#     args=TrainingArguments(
#         per_device_train_batch_size=2,
#         gradient_accumulation_steps=4,
#         num_train_epochs=3,
#         learning_rate=1e-4,

#         #  CRITICAL FIX (NO MIXED PRECISION BUG)
#         fp16=True,
#         bf16=False,

#         logging_steps=20,
#         optim="adamw_8bit",
#         weight_decay=0.01,
#         lr_scheduler_type="cosine",
#         seed=42,
#         output_dir="sft_outputs",
#         save_strategy="epoch",
#     ),
# )

# print("🚀 Training starting...")
# trainer.train()
# Out:
# Unsloth: Tokenizing ["text"] (num_proc=6):   0%|          | 0/2554 [00:00<?, ? examples/s]
# Training starting...
# ==((====))==  Unsloth - 2x faster free finetuning | Num GPUs used = 1
#    \\   /|    Num examples = 2,554 | Num Epochs = 3 | Total steps = 960
# O^O/ \_/ \    Batch size per device = 2 | Gradient accumulation steps = 4
# \        /    Data Parallel GPUs = 1 | Total batch size (2 x 4 x 1) = 8
#  "-____-"     Trainable parameters = 24,313,856 of 3,237,063,680 (0.75% trained)
# `use_return_dict` is deprecated! Use `return_dict` instead!
#     <div>
#
#       <progress value='960' max='960' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [960/960 31:55, Epoch 3/3]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>20</td>
#       <td>2.065781</td>
#     </tr>
#     <tr>
# ...

# %%
model.save_pretrained("final_model_5dprs_updated_dataset")
tokenizer.save_pretrained("final_model_5dprs_updated_dataset")

# !zip -r final_model_5dprs_updated_dataset.zip final_model_5dprs_updated_dataset/

from google.colab import files
files.download("final_model_5dprs_updated_dataset.zip")
print("Done!")
# Out:
#   adding: final_model_5dprs_updated_dataset/ (stored 0%)
#   adding: final_model_5dprs_updated_dataset/adapter_config.json (deflated 59%)
#   adding: final_model_5dprs_updated_dataset/chat_template.jinja (deflated 71%)
#   adding: final_model_5dprs_updated_dataset/README.md (deflated 65%)
#   adding: final_model_5dprs_updated_dataset/tokenizer_config.json (deflated 96%)
#   adding: final_model_5dprs_updated_dataset/tokenizer.json (deflated 85%)
#   adding: final_model_5dprs_updated_dataset/adapter_model.safetensors (deflated 8%)
# Done!
